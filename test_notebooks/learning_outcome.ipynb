# %% [markdown]
# # Stage 1: Load the Libraries

# %%
# Load the Libraries
import pandas as pd
import numpy as np
from pypdf import PdfReader
import boto3
from langchain_aws import BedrockLLM
from langchain_community.chat_models import BedrockChat

# %% [markdown]
# # Stage 2: Load the Data & LLM Definition

# %%
RESUME_FILE_PATH = "resume_extraction/data/test_resume.pdf"
SKILLS_FILE_PATH = "candidate_skills_extracted.json"

# Load the Resume
resume_reader = PdfReader(RESUME_FILE_PATH)
resume_text = ""

for page in resume_reader.pages:
    resume_text += page.extract_text()



# Load the Skills
skills= pd.read_json(SKILLS_FILE_PATH, typ="series")

print(resume_text)

# Convert skills into a JSON
skills_json = skills.to_json()

print(skills_json)
# Out:
# Ignoring wrong pointing object 6 0 (offset 0)
# Ignoring wrong pointing object 8 0 (offset 0)
# Ignoring wrong pointing object 10 0 (offset 0)
# Ignoring wrong pointing object 12 0 (offset 0)
# Ignoring wrong pointing object 14 0 (offset 0)
# Ignoring wrong pointing object 16 0 (offset 0)
# Ignoring wrong pointing object 19 0 (offset 0)
# Ignoring wrong pointing object 21 0 (offset 0)
# Ignoring wrong pointing object 23 0 (offset 0)
# Ignoring wrong pointing object 26 0 (offset 0)
# Ignoring wrong pointing object 28 0 (offset 0)
# ...

# %%
long_term_goal = """
Specific: In the next 2 years, I will become a machine learning engineer by learning the relevant skills and completing at least 2 machine learning projects.

Measurable:
- Learn and become proficient in machine learning algorithms, techniques, and tools such as Python, TensorFlow, Keras, Scikit-learn, and Pandas.
- Complete at least 2 end-to-end machine learning projects, from data collection and preprocessing to model training, evaluation, and deployment.
- Showcase the completed projects in my portfolio to demonstrate my machine learning engineering skills.

Achievable:
- Based on the resume, I have a strong foundation in programming languages and frameworks that are relevant to machine learning, including Python, SQL, and various ML libraries.
- I can utilize my existing technical skills and knowledge to quickly learn and apply machine learning concepts.
- I have the time and resources to dedicate to learning and practicing machine learning over the next 2 years.

Relevant:
- Becoming a machine learning engineer aligns with my aspiration to work in the field of artificial intelligence and data-driven decision-making.
- This goal will help me develop in-demand skills and expand my career opportunities in the technology industry.

Time-Bound:
- I will achieve this goal within the next 2 years, as specified in my original aspiration.
"""

target_skills = """
"Machine Learning Engineer" : "The text states that the role is for a Machine Learning Engineer, indicating expertise in machine learning algorithms, modeling, and engineering. This is demonstrated by the responsibility to participate in the technical design, development, and implementation of machine learning applications.",
"Agile Methodologies" : "The text mentions that the Machine Learning Engineer will be part of an Agile team, indicating experience with Agile methodologies such as Scrum or Kanban. This is demonstrated by the responsibility to work in an Agile environment to productionize machine learning applications and systems at scale.",
"Technical Design" : "The text states that the Machine Learning Engineer will participate in the detailed technical design of machine learning applications, indicating expertise in technical design. This is demonstrated by the responsibility to contribute to the technical design of machine learning applications using existing and emerging technology platforms.",
"Development" : "The text states that the Machine Learning Engineer will develop model and application code, indicating expertise in software development. This is demonstrated by the responsibility to develop and review model and application code for machine learning applications.",
"Machine Learning Architectural Design" : "The text states that the Machine Learning Engineer will focus on machine learning architectural design, indicating expertise in machine learning architecture. This is demonstrated by the responsibility to ensure high availability and performance of machine learning applications.",
"Continuous Learning" : "The text states that the Machine Learning Engineer will have the opportunity to continuously learn and apply the latest innovations and best practices in machine learning engineering, indicating a commitment to continuous learning. This is demonstrated by the responsibility to stay up-to-date with the latest innovations and best practices in machine learning engineering.",
"Feature Development" : "The text states that the Machine Learning Engineer will be responsible for feature development, indicating expertise in feature engineering. This is demonstrated by the responsibility to create monitoring solutions and integrate solutions with Marketing platforms.",
"Model Validation" : "The text states that the Machine Learning Engineer will be responsible for model validation, indicating expertise in model validation. This is demonstrated by the responsibility to build and deploy scoring pipelines and ensure high availability and performance of machine learning applications.",
"Data Engineering" : "The text states that the Machine Learning Engineer role overlaps with Data Engineering, indicating expertise in data engineering. This is demonstrated by the responsibility to create monitoring solutions and integrate solutions with Marketing platforms.",
"Streaming and Real Time ML and AI Solutions" : "The text states that the Machine Learning Engineer will be responsible for building and delivering state of the art batch, streaming and real time ML and AI solutions, indicating expertise in streaming and real time ML and AI solutions. This is demonstrated by the responsibility to build and deliver optimized ML solutions at scale."
ML engineering, demonstration of ML engineering skills through activities such as designing, building, and delivering ML models and components, writing and testing application code, developing and validating ML models, and automating tests and deployment},
{Machine Learning modeling techniques, demonstrated by informing ML infrastructure decisions using understanding of ML modeling techniques and issues, including choice of model, data, and feature selection, model training, hyperparameter tuning, dimensionality, bias/variance, and validation},
{Data Pipelines, demonstrated by constructing optimized data pipelines to feed ML models},
{Cloud-based architectures, technologies, and/or platforms, demonstrated by leveraging cloud-based architectures, technologies, and/or platforms to deliver optimized ML models at scale},
{Continuous Integration and Continuous Deployment, demonstrated by leveraging CI/CD best practices, including test automation and monitoring, to ensure successful deployment of ML models and application code},
Programming languages, demonstrated by using programming languages like Python, Scala, or Java
distributed computing", "Demonstrated 3+ years of experience in designing and building data-intensive solutions using distributed computing." },
{ "Python", "Demonstrated 4+ years of experience programming with Python." },
{ "Scala", "Demonstrated 4+ years of experience programming with Scala or Java, but no specific years of experience with Scala was mentioned." },
{ "Java", "Demonstrated 4+ years of experience programming with Scala or Java, but no specific years of experience with Java was mentioned." },
{ "ML frameworks", "Demonstrated 2+ years of experience with an industry recognized ML frameworks (scikit-learn, PyTorch, Dask, Spark, or TensorFlow). Specific experience with scikit-learn, PyTorch, Dask, Spark, or TensorFlow was not mentioned." },
{ "productionizing", "Demonstrated 1+ years of experience productionizing, monitoring, and maintaining models." },
{ "ML systems", "Preferred qualification: 1+ years of experience building, scaling, and optimizing ML systems" },
{ "data gathering", "Preferred qualification: 1+ years of experience with data gathering and preparation for ML models" },
{ "public cloud", "Preferred qualification: Experience developing and deploying ML solutions in a public cloud such as AWS" },
{ "AWS", "Preferred qualification: Experience developing and deploying ML solutions in a public cloud such as AWS" },
{ "distributed file systems", "Demonstrated 3+ years of experience with distributed file systems or multi-node database paradigms" },
{ "multi-node database paradigms", "Demonstrated 3+ years of experience with distributed file systems or multi-node database paradigms" },
{ "open source ML software", "Preferred qualification: Contributed to open source ML software" },
{ "paper", "Preferred qualification: Authored/co-authored a paper on a ML technique, model, or proof of concept" },
{ "data pipelines", "Demonstrated 3+ years of experience building production-ready data pipelines that feed ML models" },
{ "ML models", "Demonstrated 3+ years of experience building production-ready data pipelines that feed ML models" },
{ "complex data pipelines", "Demonstrated experience designing, implementing, and scaling complex data pipelines for ML models and evaluating their performance" },
{ "evaluating performance", "Demonstrated experience designing, implementing, and scaling complex data pipelines for ML models and evaluating their performance"
"""

# %%
model_id = "anthropic.claude-3-haiku-20240307-v1:0"
model_kwargs = {"temperature": 0.2, "max_tokens": 4000,"top_p": 0.1, "top_k": 50}

llm = BedrockChat(
    model_id=model_id,
    model_kwargs=model_kwargs
)
# Out:
# /Users/anshumaantyagi/Desktop/CourseRec/env/lib/python3.9/site-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The class `BedrockChat` was deprecated in LangChain 0.0.34 and will be removed in 0.3. An updated version of the class exists in the langchain-aws package and should be used instead. To use it run `pip install -U langchain-aws` and import as `from langchain_aws import ChatBedrock`.
#   warn_deprecated(

# %%
llm.invoke("Hello").content
# Out:
# 'Hello! How can I assist you today?'

# %% [markdown]
# # Stage 3 Define Prompts and Data Models

# %%
# Data Models
learning_plan_creation_prompt = """
You are a Career Counselor. 
Your task is to generate a learning plan with atleast 5 or more short-term SMART goals pertaining to the client's long-term SMART goal. 

You will be given: 
1. Skills and their explanations Extacted from Client's Resume, these will be called client's skills. 
2. Skills and their explanations Extracted from Job Descriptions about the Client's long-term SMART goal, these will be called target skills. 
3. Client's long-term SMART goal. 

Considerations: 
1. All short-term goals should contribute to the long-term goal. 
2. If there exists a pre-requisite for short term goal y , either the pre-requisite should be filled by Client's skills or a previous goal x. 
3. All goals should be personalized to Client's skill set and gaps between client's skills and target skills. 
4. One short-term goal may encapsulate, one or more gaps between client's skills and target skills but the overall goal should be achievable in the time frame required by the short-term goal. 
5. Short-term goal cumulative timeline should sum up to the time given in the long-term goal. If some goals are parallel, that should be mentioned in the timeline.
6. It is okay to have many short-term goals as long as they are SMART and contribute to the long-term goal.
7. Mention the estimated weekly commitment required for each short-term goal. For Example,3 days per week etc.

Steps for short-term goal formulation, For Each goal: 
1. Indetify the desired learning outcomes achieved at the end of the goal. 
2. Be Specific, Use action verbs to precisely define what the learner will achieve. Clearly state the scope of the objective to eliminate ambiguity. 
3. Ensure Objective are measurable, Define clear, quantifiable criteria to evaluate progress and success.Be very transparent upfront about what constitutes an excellent, good, or acceptable “pass mark.” 
4. Ensure Objectives are Acheivable, Consider the resources available and the learners’ current capabilities when setting objectives. This ensures that the goals are challenging but within reach. 
5. Ensure Objectives are Relevant/Personalized, Align the learning objectives with the overall goals of the course and the individual learner’s needs. This ensures the learning process is valuable and beneficial for the learner. 
6. Establish Deadlines/Timeframes: Set clear deadlines for each objective. Balance the time constraints with the scope of the objective to ensure it’s feasible within the given timeframe. For Each goal, Return a brief explanation about it's contribution to the overall long-term goal and it's relation to with previously completed goals or the skills given in the resume. For Each goal, Return a brief explanation about it's contribution to the overall long-term goal . 

----------------------------- 
long-term SMART goal: {long_term_goal}
client skills: {client_skills} 
target skills: {target_skills}
-----------------------------

Only return the JSON. 
------------------------------- 
Format Instruction: 
{format_instructions}
------------------------------- 
"""

learning_plan_feedback_prompt = """
You are a Career Counselor. 
Your task is to generate a learning plan with atleast 5 or more short-term SMART goals pertaining to the client's long-term SMART goal. 

You will be given: 
1. Skills and their explanations Extacted from Client's Resume, these will be called client's skills. 
2. Skills and their explanations Extracted from Job Descriptions about the Client's long-term SMART goal, these will be called target skills. 
3. Client's long-term SMART goal. 
4. A JSON containing the previous learning plan created by the user.
5. Client's Feedback on the previous learning plan.

Considerations: 
1. All short-term goals should contribute to the long-term goal. 
2. If there exists a pre-requisite for short term goal y , either the pre-requisite should be filled by Client's skills or a previous goal x. 
3. All goals should be personalized to Client's skill set and gaps between client's skills and target skills. 
4. One short-term goal may encapsulate, one or more gaps between client's skills and target skills but the overall goal should be achievable in the time frame required by the short-term goal. 
5. Short-term goal cumulative timeline should sum up to the time given in the long-term goal. If some goals are parallel, that should be mentioned in the timeline.
6. It is okay to have many short-term goals as long as they are SMART and contribute to the long-term goal.
7. Mention the estimated weekly commitment required for each short-term goal. For Example,3 days per week etc.
8. Use Client's feedback to make necessary changes to the learning plan. return the updated learning plan.
9. If the feedback is not valid, return the original learning plan and request the user to make necessary changes to the feedback.

Steps for short-term goal formulation, For Each goal: 
1. Indetify the desired learning outcomes achieved at the end of the goal. 
2. Be Specific, Use action verbs to precisely define what the learner will achieve. Clearly state the scope of the objective to eliminate ambiguity. 
3. Ensure Objective are measurable, Define clear, quantifiable criteria to evaluate progress and success.Be very transparent upfront about what constitutes an excellent, good, or acceptable “pass mark.” 
4. Ensure Objectives are Acheivable, Consider the resources available and the learners’ current capabilities when setting objectives. This ensures that the goals are challenging but within reach. 
5. Ensure Objectives are Relevant/Personalized, Align the learning objectives with the overall goals of the course and the individual learner’s needs. This ensures the learning process is valuable and beneficial for the learner. 
6. Establish Deadlines/Timeframes: Set clear deadlines for each objective. Balance the time constraints with the scope of the objective to ensure it’s feasible within the given timeframe. For Each goal, Return a brief explanation about it's contribution to the overall long-term goal and it's relation to with previously completed goals or the skills given in the resume. For Each goal, Return a brief explanation about it's contribution to the overall long-term goal . 

----------------------------- 
long-term SMART goal: {long_term_goal}
client skills: {client_skills} 
target skills: {target_skills}
feedback: {feedback}
-----------------------------

Only return the JSON. 
------------------------------- 
Format Instruction: 
{format_instructions}
------------------------------- 
"""





fix_format_instruction = """
--------------
{instructions}
--------------
Completion:
--------------
{completion}
--------------
Above, the Completion did not satisfy the constraints given in the Instructions.
Error:
--------------
{error}
--------------
Please try again. Please only respond with an answer that satisfies the constraints laid out in the Instructions.
Important:  Only correct the structural issues within the JSON format. Do not modify the existing data values themselves:
"""

# %%
from typing import List
from pydantic import BaseModel, Field

class ShortTermGoal(BaseModel):
    learning_outcomes: str = Field(..., description="Learning outcomes achieved at the end of the goal")
    specific: str = Field(..., description="Specific objective")
    measurable: str = Field(..., description="Measurable criteria to evaluate progress and success")
    achievable: str = Field(..., description="Consider the resources available and the learners’ current capabilities when setting objectives")
    relevant: str = Field(..., description="Align the learning objectives with the overall goals of the course and the individual learner’s needs")
    time_bound: str = Field(..., description="Set clear deadlines for each objective")

class LearningPlan(BaseModel):
    short_term_goals: List[ShortTermGoal] = Field(..., description="List of short-term goals")

# %%
# Define the functions
from langchain.prompts import PromptTemplate
from langchain.output_parsers import PydanticOutputParser, OutputFixingParser
from langchain.chains import TransformChain
from langchain.tools import tool

def fix_chain_fun(inputs):
    fix_prompt = PromptTemplate.from_template(fix_format_instruction)
    fix_prompt_str = fix_prompt.invoke({'instructions':inputs['instructions'],
                                        'completion':inputs['completion'],
                                        'error':inputs['error']}).text
    
    #print(fix_prompt_str)
    
    completion = llm.invoke(fix_prompt_str).content

    # return {"completion": completion}
    
    return {"completion": completion}

fix_chain = TransformChain(
    input_variables = ["instructions", "completion", "error"],output_variables=["completion"], transform=fix_chain_fun
)

@tool(parse_docstring=True)
def generate_learning_plan(long_term_goal: str, client_skills: str, target_skills: str) -> str:
    """Takes a long-term goal, client's skills, and target skills and generates a learning plan with short-term SMART goals.
    
    Args:
        long_term_goal: The long-term SMART goal of the client.
        client_skills: ALL of the skills and their explanations extracted from the client's resume.
        target_skills: All of the target skills and their explanations extracted from job descriptions about the client's long-term SMART goal.
    """
    
    # Inputs
    inputs = ["long_term_goal", "client_skills", "target_skills"]
    # Define the parser
    parser = PydanticOutputParser(pydantic_object=LearningPlan)

    fix_parser = OutputFixingParser(parser=parser, retry_chain=fix_chain, max_retries=2)

    # Define the chain
    prompt = PromptTemplate(
        template=learning_plan_creation_prompt,
        inputs=inputs,
        partial_variables={"format_instructions":parser.get_format_instructions()}  
    )

    prompt_str = prompt.format(long_term_goal=long_term_goal, client_skills=client_skills, target_skills=target_skills)
    print(f"prompt is {prompt_str}")
    response = llm.invoke(prompt_str).content

    print(response)
    fixed_response = fix_parser.invoke(response)

    return fixed_response

@tool(parse_docstring=True)
def edit_learning_plan(long_term_goal: str, client_skills: str, target_skills: str, learning_plan: str, feedback: str) -> str:
    """Responsible for editing the learning plan using user feedback and previous learning plan. Takes a long-term goal, client's skills,target skills, previous learning plan and feedback and generates a new learning plan.
    
    Args:
        long_term_goal: The long-term SMART goal of the client.
        client_skills: ALL of the skills and their explanations extracted from the client's resume.
        target_skills: All of the target skills and their explanations extracted from job descriptions about the client's long-term SMART goal.
        learning_plan: The whole previous learning plan created by the user.
        feedback: The feedback given by the user on the previous learning plan.
    """
    
    # Inputs
    inputs = ["long_term_goal", "client_skills", "target_skills", "learning_plan", "feedback"]
    # Define the parser
    parser = PydanticOutputParser(pydantic_object=LearningPlan)

    fix_parser = OutputFixingParser(parser=parser, retry_chain=fix_chain, max_retries=2)

    # Define the chain
    prompt = PromptTemplate(
        template=learning_plan_creation_prompt,
        inputs=inputs,
        partial_variables={"format_instructions":parser.get_format_instructions()}  
    )

    prompt_str = prompt.format(long_term_goal=long_term_goal, client_skills=client_skills, target_skills=target_skills, learning_plan=learning_plan, feedback=feedback)
    print(f"prompt is {prompt_str}")
    response = llm.invoke(prompt_str).content

    print(response)
    fixed_response = fix_parser.invoke(response)

    return fixed_response


generate_learning_plan.args_schema.schema()
# Out:
# {'title': 'generate_learning_planSchema',
#  'description': "Takes a long-term goal, client's skills, and target skills and generates a learning plan with short-term SMART goals.",
#  'type': 'object',
#  'properties': {'long_term_goal': {'title': 'Long Term Goal',
#    'description': 'The long-term SMART goal of the client.',
#    'type': 'string'},
#   'client_skills': {'title': 'Client Skills',
#    'description': "ALL of the skills and their explanations extracted from the client's resume.",
#    'type': 'string'},
#   'target_skills': {'title': 'Target Skills',
#    'description': "All of the target skills and their explanations extracted from job descriptions about the client's long-term SMART goal.",
#    'type': 'string'}},
#  'required': ['long_term_goal', 'client_skills', 'target_skills']}

# %%
# Generate the Learning Plan

learning_plan = generate_learning_plan(long_term_goal=long_term_goal, client_skills=skills, target_skills=target_skills)
# Out:
# /Users/anshumaantyagi/Desktop/CourseRec/env/lib/python3.9/site-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The method `BaseTool.__call__` was deprecated in langchain-core 0.1.47 and will be removed in 0.3.0. Use invoke instead.
#   warn_deprecated(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 # Generate the Learning Plan
# ----> 3 learning_plan = generate_learning_plan(long_term_goal=long_term_goal, client_skills=skills, target_skills=target_skills)
#
# File ~/Desktop/CourseRec/env/lib/python3.9/site-packages/langchain_core/_api/deprecation.py:168, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     166     warned = True
#     167     emit_warning()
# --> 168 return wrapped(*args, **kwargs)
#
# TypeError: __call__() got an unexpected keyword argument 'long_term_goal'

# %%
print(learning_plan)
# Out:
# short_term_goals=[ShortTermGoal(learning_outcomes='Gain proficiency in core machine learning algorithms, techniques, and tools such as Python, TensorFlow, Keras, Scikit-learn, and Pandas.', specific='Complete a comprehensive online course or tutorial series on machine learning fundamentals, covering topics like supervised and unsupervised learning, regression, classification, clustering, and neural networks.', measurable='Achieve a score of at least 85% on the course assessments and be able to implement basic machine learning models using the covered tools and libraries.', achievable='Leverage my existing programming skills in Python and familiarity with data manipulation libraries to quickly learn and apply machine learning concepts.', relevant='This goal will provide the necessary foundation and skills to start working on more complex machine learning projects.', time_bound='Complete the course within the first 3 months of the 2-year timeline.'), ShortTermGoal(learning_outcomes='De
# ...

# %%
# Save Learning plan to JSON
import json
with open("learning_plan-1.json", "w") as f:
    json.dump(learning_plan.dict(), f, indent=4)

# %% [markdown]
# # Stage 4: Building an Agent

# %%
from langchain_core.messages import HumanMessage
from langgraph.checkpoint.sqlite import SqliteSaver
from langgraph.checkpoint import MemorySaver
from langgraph.prebuilt import create_react_agent
from langchain_aws import ChatBedrock
from langchain_core.tools import tool

# %% [markdown]
# ## Stage 2 : Defining Global Variables

# %%
learning_outcomes = {}
# memory = SqliteSaver.from_conn_string(":memory:")
memory = MemorySaver()
model = ChatBedrock(model_id ="anthropic.claude-3-haiku-20240307-v1:0", model_kwargs={"temperature": 0, "max_tokens":6000, "top_p":0.1,"top_k":50})
tools = [generate_learning_plan, edit_learning_plan]
agent_executor = create_react_agent(model, tools, checkpointer=memory)

# %%
q1 = f"Hey, Generate a learning plan for the me with long-term goal: {long_term_goal} and client skills: {skills_json} and target skills: {target_skills}."
config = {"configurable": {"thread_id": "abc123"}}


for chunk in agent_executor.stream(
{"messages": [HumanMessage(content=q1)]}, config
):
    print(chunk)
    print("----")
# Out:
# {'agent': {'messages': [AIMessage(content='', additional_kwargs={'usage': {'prompt_tokens': 3198, 'completion_tokens': 1347, 'total_tokens': 4545}, 'stop_reason': 'tool_use', 'model_id': 'anthropic.claude-3-haiku-20240307-v1:0'}, response_metadata={'usage': {'prompt_tokens': 3198, 'completion_tokens': 1347, 'total_tokens': 4545}, 'stop_reason': 'tool_use', 'model_id': 'anthropic.claude-3-haiku-20240307-v1:0'}, id='run-54803519-9195-4c9f-b71b-d00528490416-0', tool_calls=[{'name': 'generate_learning_plan', 'args': {'long_term_goal': 'In the next 2 years, I will become a machine learning engineer by learning the relevant skills and completing at least 2 machine learning projects.', 'client_skills': '{"python":"Used Python to design server applications and client interfaces in the role of Software Engineer(Backend Developer) at NUS CommIT.","java":"Not explicitly demonstrated in the text.","sql":"Studied industrial application of SQL database use cases and it\'s deployment in the role of
# ...

# %%
long_term_goal = """
Specific: In the next 2 years, I will become a machine learning engineer by learning the relevant skills and completing at least 2 machine learning projects.

Measurable:
- Learn and become proficient in machine learning algorithms, techniques, and tools such as Python, TensorFlow, Keras, Scikit-learn, and Pandas.
- Complete at least 2 end-to-end machine learning projects, from data collection and preprocessing to model training, evaluation, and deployment.
- Showcase the completed projects in my portfolio to demonstrate my machine learning engineering skills.

Achievable:
- Based on the resume, I have a strong foundation in programming languages and frameworks that are relevant to machine learning, including Python, SQL, and various ML libraries.
- I can utilize my existing technical skills and knowledge to quickly learn and apply machine learning concepts.
- I have the time and resources to dedicate to learning and practicing machine learning over the next 2 years.

Relevant:
- Becoming a machine learning engineer aligns with my aspiration to work in the field of artificial intelligence and data-driven decision-making.
- This goal will help me develop in-demand skills and expand my career opportunities in the technology industry.

Time-Bound:
- I will achieve this goal within the next 2 years, as specified in my original aspiration.
"""

target_skills = """
"Machine Learning Engineer" : "The text states that the role is for a Machine Learning Engineer, indicating expertise in machine learning algorithms, modeling, and engineering. This is demonstrated by the responsibility to participate in the technical design, development, and implementation of machine learning applications.",
"Agile Methodologies" : "The text mentions that the Machine Learning Engineer will be part of an Agile team, indicating experience with Agile methodologies such as Scrum or Kanban. This is demonstrated by the responsibility to work in an Agile environment to productionize machine learning applications and systems at scale.",
"Technical Design" : "The text states that the Machine Learning Engineer will participate in the detailed technical design of machine learning applications, indicating expertise in technical design. This is demonstrated by the responsibility to contribute to the technical design of machine learning applications using existing and emerging technology platforms.",
"Development" : "The text states that the Machine Learning Engineer will develop model and application code, indicating expertise in software development. This is demonstrated by the responsibility to develop and review model and application code for machine learning applications.",
"Machine Learning Architectural Design" : "The text states that the Machine Learning Engineer will focus on machine learning architectural design, indicating expertise in machine learning architecture. This is demonstrated by the responsibility to ensure high availability and performance of machine learning applications.",
"Continuous Learning" : "The text states that the Machine Learning Engineer will have the opportunity to continuously learn and apply the latest innovations and best practices in machine learning engineering, indicating a commitment to continuous learning. This is demonstrated by the responsibility to stay up-to-date with the latest innovations and best practices in machine learning engineering.",
"Feature Development" : "The text states that the Machine Learning Engineer will be responsible for feature development, indicating expertise in feature engineering. This is demonstrated by the responsibility to create monitoring solutions and integrate solutions with Marketing platforms.",
"Model Validation" : "The text states that the Machine Learning Engineer will be responsible for model validation, indicating expertise in model validation. This is demonstrated by the responsibility to build and deploy scoring pipelines and ensure high availability and performance of machine learning applications.",
"Data Engineering" : "The text states that the Machine Learning Engineer role overlaps with Data Engineering, indicating expertise in data engineering. This is demonstrated by the responsibility to create monitoring solutions and integrate solutions with Marketing platforms.",
"Streaming and Real Time ML and AI Solutions" : "The text states that the Machine Learning Engineer will be responsible for building and delivering state of the art batch, streaming and real time ML and AI solutions, indicating expertise in streaming and real time ML and AI solutions. This is demonstrated by the responsibility to build and deliver optimized ML solutions at scale."
ML engineering, demonstration of ML engineering skills through activities such as designing, building, and delivering ML models and components, writing and testing application code, developing and validating ML models, and automating tests and deployment},
{Machine Learning modeling techniques, demonstrated by informing ML infrastructure decisions using understanding of ML modeling techniques and issues, including choice of model, data, and feature selection, model training, hyperparameter tuning, dimensionality, bias/variance, and validation},
{Data Pipelines, demonstrated by constructing optimized data pipelines to feed ML models},
{Cloud-based architectures, technologies, and/or platforms, demonstrated by leveraging cloud-based architectures, technologies, and/or platforms to deliver optimized ML models at scale},
{Continuous Integration and Continuous Deployment, demonstrated by leveraging CI/CD best practices, including test automation and monitoring, to ensure successful deployment of ML models and application code},
Programming languages, demonstrated by using programming languages like Python, Scala, or Java
distributed computing", "Demonstrated 3+ years of experience in designing and building data-intensive solutions using distributed computing." },
{ "Python", "Demonstrated 4+ years of experience programming with Python." },
{ "Scala", "Demonstrated 4+ years of experience programming with Scala or Java, but no specific years of experience with Scala was mentioned." },
{ "Java", "Demonstrated 4+ years of experience programming with Scala or Java, but no specific years of experience with Java was mentioned." },
{ "ML frameworks", "Demonstrated 2+ years of experience with an industry recognized ML frameworks (scikit-learn, PyTorch, Dask, Spark, or TensorFlow). Specific experience with scikit-learn, PyTorch, Dask, Spark, or TensorFlow was not mentioned." },
{ "productionizing", "Demonstrated 1+ years of experience productionizing, monitoring, and maintaining models." },
{ "ML systems", "Preferred qualification: 1+ years of experience building, scaling, and optimizing ML systems" },
{ "data gathering", "Preferred qualification: 1+ years of experience with data gathering and preparation for ML models" },
{ "public cloud", "Preferred qualification: Experience developing and deploying ML solutions in a public cloud such as AWS" },
{ "AWS", "Preferred qualification: Experience developing and deploying ML solutions in a public cloud such as AWS" },
{ "distributed file systems", "Demonstrated 3+ years of experience with distributed file systems or multi-node database paradigms" },
{ "multi-node database paradigms", "Demonstrated 3+ years of experience with distributed file systems or multi-node database paradigms" },
{ "open source ML software", "Preferred qualification: Contributed to open source ML software" },
{ "paper", "Preferred qualification: Authored/co-authored a paper on a ML technique, model, or proof of concept" },
{ "data pipelines", "Demonstrated 3+ years of experience building production-ready data pipelines that feed ML models" },
{ "ML models", "Demonstrated 3+ years of experience building production-ready data pipelines that feed ML models" },
{ "complex data pipelines", "Demonstrated experience designing, implementing, and scaling complex data pipelines for ML models and evaluating their performance" },
{ "evaluating performance", "Demonstrated experience designing, implementing, and scaling complex data pipelines for ML models and evaluating their performance"
"""

client_skills = """
"Python": "Proficient in Python programming language with 4+ years of experience.",
"SQL": "Experience with SQL databases and queries.",
"Machine Learning Libraries": "Familiarity with machine learning libraries such as scikit-learn, TensorFlow, and PyTorch.",
"Data Preprocessing": "Experience in data preprocessing techniques such as cleaning, transformation, and feature engineering.",
"Model Training": "Experience in training machine learning models on datasets.",
"Model Evaluation": "Knowledge of model evaluation metrics and techniques.",
"""


q1 = f"Hey, Generate a learning plan for the me with long-term goal: {long_term_goal} and client skills: {client_skills} and target skills: {target_skills}."

for chunk in agent_executor.stream(
{"messages": [HumanMessage(content=q1)]}, config
):
    print(chunk)
    print("----")
# Out:
# {'agent': {'messages': [AIMessage(content='', additional_kwargs={'usage': {'prompt_tokens': 7459, 'completion_tokens': 787, 'total_tokens': 8246}, 'stop_reason': 'tool_use', 'model_id': 'anthropic.claude-3-haiku-20240307-v1:0'}, response_metadata={'usage': {'prompt_tokens': 7459, 'completion_tokens': 787, 'total_tokens': 8246}, 'stop_reason': 'tool_use', 'model_id': 'anthropic.claude-3-haiku-20240307-v1:0'}, id='run-3b268da3-c063-4af0-a88d-d1e97db31e5a-0', tool_calls=[{'name': 'generate_learning_plan', 'args': {'client_skills': '{"Python": "Proficient in Python programming language with 4+ years of experience.", "SQL": "Experience with SQL databases and queries.", "Machine Learning Libraries": "Familiarity with machine learning libraries such as scikit-learn, TensorFlow, and PyTorch.", "Data Preprocessing": "Experience in data preprocessing techniques such as cleaning, transformation, and feature engineering.", "Model Training": "Experience in training machine learning models on data
# ...

# %%
configurations = memory.get({"configurable": {"thread_id": "abc123"}})

# Store the configurations in a file as a text
with open("configurations.txt", "w") as f:
    f.write(str(configurations))

# %%
q2 = f"what specifically is me second goal? Only give me the specific objective."
config = {"configurable": {"thread_id": "abc123"}}


for chunk in agent_executor.stream(
{"messages": [HumanMessage(content=q2)]}, config
):
    print(chunk)
    print("----")
# Out:
# {'agent': {'messages': [AIMessage(content='The specific objective for the second short-term goal is:\n\nComplete a comprehensive online course or specialization on machine learning, covering topics such as supervised and unsupervised learning, model selection, and evaluation.', additional_kwargs={'usage': {'prompt_tokens': 5831, 'completion_tokens': 46, 'total_tokens': 5877}, 'stop_reason': 'end_turn', 'model_id': 'anthropic.claude-3-haiku-20240307-v1:0'}, response_metadata={'usage': {'prompt_tokens': 5831, 'completion_tokens': 46, 'total_tokens': 5877}, 'stop_reason': 'end_turn', 'model_id': 'anthropic.claude-3-haiku-20240307-v1:0'}, id='run-83390548-1b19-4cef-9045-ab2a84a22fb9-0', usage_metadata={'input_tokens': 5831, 'output_tokens': 46, 'total_tokens': 5877})]}}
# ----

# %%
q3 = f"I already have an internship as an AI Developer, can you modify my learning plan to include this, so I don't end up repeating the stuff I did at my internship?"
config = {"configurable": {"thread_id": "abc123"}}


for chunk in agent_executor.stream(
{"messages": [HumanMessage(content=q3)]}, config
):
    print(chunk)
    print("----")
# Out:
# {'agent': {'messages': [AIMessage(content='', additional_kwargs={'usage': {'prompt_tokens': 5918, 'completion_tokens': 2502, 'total_tokens': 8420}, 'stop_reason': 'tool_use', 'model_id': 'anthropic.claude-3-haiku-20240307-v1:0'}, response_metadata={'usage': {'prompt_tokens': 5918, 'completion_tokens': 2502, 'total_tokens': 8420}, 'stop_reason': 'tool_use', 'model_id': 'anthropic.claude-3-haiku-20240307-v1:0'}, id='run-a4c91c7e-5701-4cbc-bc0d-e67020831311-0', tool_calls=[{'name': 'edit_learning_plan', 'args': {'long_term_goal': 'In the next 2 years, I will become a machine learning engineer by learning the relevant skills and completing at least 2 machine learning projects.', 'client_skills': '{"python":"Used Python to design server applications and client interfaces in the role of Software Engineer(Backend Developer) at NUS CommIT.","java":"Not explicitly demonstrated in the text.","sql":"Studied industrial application of SQL database use cases and it\'s deployment in the role of Ful
# ...
